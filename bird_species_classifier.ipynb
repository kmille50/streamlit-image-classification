# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/chriamue/bird-species-classifier
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/chriamue/bird-species-classifier)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-classification", model="chriamue/bird-species-classifier")
pipe("./streamlit-image-classification/cats.jpg")
# Out:
# Loading weights: 100%|██████████| 508/508 [00:00<00:00, 1098.42it/s, Materializing param=efficientnet.encoder.top_conv.weight]
# [{'label': 'EGYPTIAN GOOSE', 'score': 0.21686789393424988},
#  {'label': 'LONG-EARED OWL', 'score': 0.11700878292322159},
#  {'label': 'JACOBIN PIGEON', 'score': 0.0860225036740303},
#  {'label': 'GUINEA TURACO', 'score': 0.06820261478424072},
#  {'label': 'LOONEY BIRDS', 'score': 0.05975550785660744}]

# %%
# Load model directly
from transformers import AutoImageProcessor, AutoModelForImageClassification

processor = AutoImageProcessor.from_pretrained("chriamue/bird-species-classifier")
model = AutoModelForImageClassification.from_pretrained("chriamue/bird-species-classifier")
# Out:
# Loading weights: 100%|██████████| 508/508 [00:00<00:00, 1066.70it/s, Materializing param=efficientnet.encoder.top_conv.weight]

# %% [markdown]
# ## Remote Inference via Inference Providers
# Ensure you have a valid **HF_TOKEN** set in your environment. You can get your token from [your settings page](https://huggingface.co/settings/tokens). Note: running this may incur charges above the free tier.
# The following Python example shows how to run the model remotely on HF Inference Providers, automatically selecting an available inference provider for you.
# For more information on how to use the Inference Providers, please refer to our [documentation and guides](https://huggingface.co/docs/inference-providers/en/index).

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="auto",
    api_key=os.environ["HF_TOKEN"],
)

output = client.image_classification("cats.jpg", model="chriamue/bird-species-classifier")

print(output)
# Out:
# [ImageClassificationOutputElement(label='EGYPTIAN GOOSE', score=0.21686780452728271), ImageClassificationOutputElement(label='LONG-EARED OWL', score=0.11700902134180069), ImageClassificationOutputElement(label='JACOBIN PIGEON', score=0.08602249622344971), ImageClassificationOutputElement(label='GUINEA TURACO', score=0.06820274889469147), ImageClassificationOutputElement(label='LOONEY BIRDS', score=0.059755366295576096)]
